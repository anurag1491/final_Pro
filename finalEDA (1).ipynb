# %%
import pandas as pandas
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train = pandas.read_csv("train.csv")
test = pandas.read_csv("test.csv")

# %%
test
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# 5     2011-01-20 05:00:00       1        0           1        1   9.84
# 6     2011-01-20 06:00:00       1        0           1        1   9.02
# 7     2011-01-20 07:00:00       1        0           1        1   9.02
# 8     2011-01-20 08:00:00       1        0           1        1   9.02
# 9     2011-01-20 09:00:00       1        0           1        2   9.84
# 10    2011-01-20 10:00:00       1        0           1        1  10.66
# 11    2011-01-20 11:00:00       1        0           1        2  11.48
# ...

# %% [markdown]
# ###checking missing values for train

# %%
train.isnull()
# Out:
#       datetime season holiday workingday weather   temp  atemp humidity  \
# 0        False  False   False      False   False  False  False    False
# 1        False  False   False      False   False  False  False    False
# 2        False  False   False      False   False  False  False    False
# 3        False  False   False      False   False  False  False    False
# 4        False  False   False      False   False  False  False    False
# 5        False  False   False      False   False  False  False    False
# 6        False  False   False      False   False  False  False    False
# 7        False  False   False      False   False  False  False    False
# 8        False  False   False      False   False  False  False    False
# 9        False  False   False      False   False  False  False    False
# 10       False  False   False      False   False  False  False    False
# 11       False  False   False      False   False  False  False    False
# ...

# %% [markdown]
# ###checking missing values for datetime

# %%
test[test.datetime.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %% [markdown]
# ###checking missing values for season

# %%
test[test.season.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.season.value_counts().plot(kind="bar")

# %% [markdown]
# ###checking missing values for holiday

# %%
test[test.holiday.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.holiday.value_counts().plot(kind="bar")

# %% [markdown]
# ###Checking missing values for workingday

# %%
test[test.workingday.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.workingday.value_counts().plot(kind="bar")

# %% [markdown]
# ###Checking missing values for weather

# %%
test[test.weather.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.weather.value_counts().plot(kind="bar")

# %% [markdown]
# ###Checking missing values for temp

# %%
test[test.temp.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.temp.describe()
# Out:
# count    6493.000000
# mean       20.620607
# std         8.059583
# min         0.820000
# 25%        13.940000
# 50%        21.320000
# 75%        27.060000
# max        40.180000
# dtype: float64

# %%
test.temp.hist(bins = 8)

# %%
test.temp.value_counts().plot(kind="bar")

# %% [markdown]
# ###Checking missing values for atemp

# %%
test[test.atemp.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.atemp.describe()
# Out:
# count    6493.000000
# mean       24.012865
# std         8.782741
# min         0.000000
# 25%        16.665000
# 50%        25.000000
# 75%        31.060000
# max        50.000000
# dtype: float64

# %%
test.atemp.hist(bins = 8)

# %%
test.atemp.value_counts().plot(kind="bar")

# %% [markdown]
# ###Checking missing values for humidity

# %%
test[test.humidity.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.humidity.describe()
# Out:
# count    6493.000000
# mean       64.125212
# std        19.293391
# min        16.000000
# 25%        49.000000
# 50%        65.000000
# 75%        81.000000
# max       100.000000
# dtype: float64

# %%
test.humidity.hist(bins = 10)

# %%
test.humidity.value_counts().plot(kind="bar")

# %% [markdown]
# ###Checking missing values for windspeed

# %%
test[test.windspeed.isnull()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %%
test.windspeed.describe()
# Out:
# count    6493.000000
# mean       12.631157
# std         8.250151
# min         0.000000
# 25%         7.001500
# 50%        11.001400
# 75%        16.997900
# max        55.998600
# dtype: float64

# %%
test.windspeed.hist(bins = 8)

# %%
test.windspeed.value_counts().plot(kind="bar")
